# %%
import pandas as pd
import os
os.chdir("..")

# %%
df = pd.read_parquet("data/synthetic/positive_raw.parquet")
print(f"Generated: {len(df)} | Unique seeds: {df['seed_sentence'].nunique()}")
# Out:
# Generated: 1348 | Unique seeds: 674
