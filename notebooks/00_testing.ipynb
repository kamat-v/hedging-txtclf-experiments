# %%
import pandas as pd
import os
os.chdir("..")
df = pd.read_parquet("data/synthetic/positive_raw.parquet")
print(f"Generated so far: {len(df)}")
print(f"Unique seeds: {df['seed_sentence'].nunique()}")
# Out:
# Generated so far: 1924
# Unique seeds: 962
