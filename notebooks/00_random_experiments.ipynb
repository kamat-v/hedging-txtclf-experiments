# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir("..")

# %%
pd.set_option('display.max_colwidth', None)

# %%
# load parquet
df = pd.read_parquet("data/processed/train.parquet")   # change path if needed

labels = df["label"]

# count 0/1
counts = labels.value_counts().sort_index()

plt.figure(figsize=(6,4))
plt.bar(counts.index, counts.values)
plt.xticks([0,1])
plt.yticks([])
#plt.title("Training Data Imbalance")
plt.show()

# %%
df_label_1 = df[df['label'] == 1].copy()

# %%
random_ten=df_label_1.sample(n=10)
print(random_ten['sentence'])
# Out:
# 7083                            It’s really hard to say how a shifting dollar is going to impact that and, honestly, what will actually happen there, but I would just say if we take a step back and we think about our guidance here, our process, we’re just planning prudently and preparing for some level of uncertainty.
# 18913                                                                                                  And we think it's the right step now to look at resource allocation and allocate resources to businesses we think how higher growth potential and therefore, making a bigger focus on profitability in the VMS business.
# 60737                                                                                                                                            It is possible that economic activity in China might improve with actions that the Chinese government might take in the future, but we have not included that in our forecast.
# ...
